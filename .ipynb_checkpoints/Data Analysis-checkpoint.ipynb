# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as PercentFormatter
import numpy as np

# %%
df = pd.read_excel("Concept_Data Resep.xlsx")
df
# Out:
#       id               nama_resep  \
# 0      1          Bubur Hati Ayam
# 1      2   Bubur Hati Ayam Santan
# 2      3    Bubur Pepes Hati Ayam
# 3      4         Bubur Udang Tahu
# 4      5       Bubur Udang Buncis
# ..   ...                      ...
# 201  202      Ikan Dori Saus Mayo
# 202  203          Beef Stroganoff
# 203  204    Buffalo Chicken Toast
# 204  205  Pancake Satan Keju Madu
# 205  206           Egg Mayo Sando
#
#                                            bahan_resep      bahan_alergen  \
# 0    nasi, hati ayam, bayam, minyak jagung, garam, ...                NaN
# 1    nasi, hati ayam, wortel, santan, minyak kelapa...                NaN
# 2    nasi, hati ayam, wortel, minyak kelapa, tomat,...                NaN
# 3    nasi, udang giling, santan, tahu, tomat, keman...        udang, tahu
# 4    nasi, udang giling, buncis, minyak jagung, jer...              udang
# ..                                                 ...                ...
# 201  ikan dori, brokoli, tomat merah, mayonnaise, l...   ikan, mayonnaise
# 202  daging wagyu, mentega truffle garlic, bawang b...   mayonnaise, krim
# 203  ayam bagian dada, mayonnaise, lada hitam, hima...   roti, mayonnaise
# 204  bubuk pancake, santan kara, susu uht full crea...   keju, mayonnaise
# 205  mayonnaise, roti tawar putih, telur puyuh, sus...  susu, roti, telur
#
#     daerah_resep umur_resep
# 0      Indonesia  6-8 Bulan
# 1      Indonesia  6-8 Bulan
# 2      Indonesia  6-8 Bulan
# 3      Indonesia  6-8 Bulan
# 4      Indonesia  6-8 Bulan
# ..           ...        ...
# 201    Indonesia  6-8 Bulan
# 202    Indonesia  6-8 Bulan
# 203    Indonesia  6-8 Bulan
# 204    Indonesia  6-8 Bulan
# 205    Indonesia  6-8 Bulan
#
# [206 rows x 6 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['bahan_alergen'] = df['bahan_alergen'].str.split(',') #split alergi yg lebih dari satu
df = df.explode('bahan_alergen') #new row untuk yg dipisah
df
# Out:
#       id               nama_resep  \
# 0      1          Bubur Hati Ayam
# 1      2   Bubur Hati Ayam Santan
# 2      3    Bubur Pepes Hati Ayam
# 3      4         Bubur Udang Tahu
# 3      4         Bubur Udang Tahu
# ..   ...                      ...
# 204  205  Pancake Satan Keju Madu
# 204  205  Pancake Satan Keju Madu
# 205  206           Egg Mayo Sando
# 205  206           Egg Mayo Sando
# 205  206           Egg Mayo Sando
#
#                                            bahan_resep bahan_alergen  \
# 0    nasi, hati ayam, bayam, minyak jagung, garam, ...           NaN
# 1    nasi, hati ayam, wortel, santan, minyak kelapa...           NaN
# 2    nasi, hati ayam, wortel, minyak kelapa, tomat,...           NaN
# 3    nasi, udang giling, santan, tahu, tomat, keman...         udang
# 3    nasi, udang giling, santan, tahu, tomat, keman...          tahu
# ..                                                 ...           ...
# 204  bubuk pancake, santan kara, susu uht full crea...          keju
# 204  bubuk pancake, santan kara, susu uht full crea...    mayonnaise
# 205  mayonnaise, roti tawar putih, telur puyuh, sus...          susu
# 205  mayonnaise, roti tawar putih, telur puyuh, sus...          roti
# 205  mayonnaise, roti tawar putih, telur puyuh, sus...         telur
#
#     daerah_resep umur_resep
# 0      Indonesia  6-8 Bulan
# 1      Indonesia  6-8 Bulan
# 2      Indonesia  6-8 Bulan
# 3      Indonesia  6-8 Bulan
# 3      Indonesia  6-8 Bulan
# ..           ...        ...
# 204    Indonesia  6-8 Bulan
# 204    Indonesia  6-8 Bulan
# 205    Indonesia  6-8 Bulan
# 205    Indonesia  6-8 Bulan
# 205    Indonesia  6-8 Bulan
#
# [394 rows x 6 columns]

# %%
df['bahan_alergen'] = df['bahan_alergen'].str.lstrip()
df
# Out:
#       id               nama_resep  \
# 0      1          Bubur Hati Ayam
# 1      2   Bubur Hati Ayam Santan
# 2      3    Bubur Pepes Hati Ayam
# 3      4         Bubur Udang Tahu
# 3      4         Bubur Udang Tahu
# ..   ...                      ...
# 204  205  Pancake Satan Keju Madu
# 204  205  Pancake Satan Keju Madu
# 205  206           Egg Mayo Sando
# 205  206           Egg Mayo Sando
# 205  206           Egg Mayo Sando
#
#                                            bahan_resep bahan_alergen  \
# 0    nasi, hati ayam, bayam, minyak jagung, garam, ...           NaN
# 1    nasi, hati ayam, wortel, santan, minyak kelapa...           NaN
# 2    nasi, hati ayam, wortel, minyak kelapa, tomat,...           NaN
# 3    nasi, udang giling, santan, tahu, tomat, keman...         udang
# 3    nasi, udang giling, santan, tahu, tomat, keman...          tahu
# ..                                                 ...           ...
# 204  bubuk pancake, santan kara, susu uht full crea...          keju
# 204  bubuk pancake, santan kara, susu uht full crea...    mayonnaise
# 205  mayonnaise, roti tawar putih, telur puyuh, sus...          susu
# 205  mayonnaise, roti tawar putih, telur puyuh, sus...          roti
# 205  mayonnaise, roti tawar putih, telur puyuh, sus...         telur
#
#     daerah_resep umur_resep
# 0      Indonesia  6-8 Bulan
# 1      Indonesia  6-8 Bulan
# 2      Indonesia  6-8 Bulan
# 3      Indonesia  6-8 Bulan
# 3      Indonesia  6-8 Bulan
# ..           ...        ...
# 204    Indonesia  6-8 Bulan
# 204    Indonesia  6-8 Bulan
# 205    Indonesia  6-8 Bulan
# 205    Indonesia  6-8 Bulan
# 205    Indonesia  6-8 Bulan
#
# [394 rows x 6 columns]

# %%
#export data
df.to_csv('cleaned_data.csv', index=False)

# %%
count = df.groupby('bahan_alergen').size()
count
# Out:
# bahan_alergen
# Mie                1
# gelatin            1
# ikan              44
# kacang            28
# kecap             11
# keju              40
# kerupuk udang      1
# krim               1
# mayonnaise         9
# mentega           18
# mie                2
# minyak kedelai     3
# minyak wijen       6
# pasta              9
# roti              14
# saus               1
# saus tiram         1
# susu              32
# tahu              31
# telur             40
# tempe             14
# tepung            38
# tiram              1
# tofu               2
# udang             10
# yogurt             8
# dtype: int64

# %%
#karena beberapa resep tidak ada mengandung beberapa kategori alergen
#krim, whey, kasein, mayonnaise, meringue, minyak ikan, gelatin ikan, ebi, petis, terasi, kerupuk udang, koya, kerang, mustard, kerupuk kedelai, bumbu kacang

new_rows = [#{'bahan_alergen': 'krim', 'total_resep': 0},
            {'bahan_alergen': 'whey', 'total_resep': 0},
            {'bahan_alergen': 'kasein', 'total_resep': 0},
            #{'bahan_alergen': 'mayonnaise', 'total_resep': 0},
            {'bahan_alergen': 'meringue', 'total_resep': 0},
            {'bahan_alergen': 'minyak ikan', 'total_resep': 0},
            {'bahan_alergen': 'gelatin ikan', 'total_resep': 0},
            #{'bahan_alergen': 'ebi', 'total_resep': 0},
            {'bahan_alergen': 'petis', 'total_resep': 0},
            {'bahan_alergen': 'terasi', 'total_resep': 0},
            #{'bahan_alergen': 'kerupuk udang', 'total_resep': 0},
            {'bahan_alergen': 'koya', 'total_resep': 0},
            {'bahan_alergen': 'kerang', 'total_resep': 0},
            {'bahan_alergen': 'mustard', 'total_resep': 0},
            {'bahan_alergen': 'kerupuk kedelai', 'total_resep': 0},
            {'bahan_alergen': 'bumbu kacang', 'total_resep': 0}]

df_y = pd.DataFrame(new_rows)

# %%
df_v = df.groupby('bahan_alergen')['nama_resep'].count().reset_index()
df_v.columns = ['bahan_alergen', 'total_resep']
df_v
# Out:
#      bahan_alergen  total_resep
# 0              Mie            1
# 1          gelatin            1
# 2             ikan           44
# 3           kacang           28
# 4            kecap           11
# 5             keju           40
# 6    kerupuk udang            1
# 7             krim            1
# 8       mayonnaise            9
# 9          mentega           18
# 10             mie            2
# 11  minyak kedelai            3
# 12    minyak wijen            6
# 13           pasta            9
# 14            roti           14
# 15            saus            1
# 16      saus tiram            1
# 17            susu           32
# 18            tahu           31
# 19           telur           40
# 20           tempe           14
# 21          tepung           38
# 22           tiram            1
# 23            tofu            2
# 24           udang           10
# 25          yogurt            8

# %%
df_v = pd.concat([df_v, df_y], ignore_index=True)

# %%
df_v
# Out:
#       bahan_alergen  total_resep
# 0               Mie            1
# 1           gelatin            1
# 2              ikan           44
# 3            kacang           28
# 4             kecap           11
# 5              keju           40
# 6     kerupuk udang            1
# 7              krim            1
# 8        mayonnaise            9
# 9           mentega           18
# 10              mie            2
# 11   minyak kedelai            3
# 12     minyak wijen            6
# 13            pasta            9
# 14             roti           14
# 15             saus            1
# 16       saus tiram            1
# 17             susu           32
# 18             tahu           31
# 19            telur           40
# 20            tempe           14
# 21           tepung           38
# 22            tiram            1
# 23             tofu            2
# 24            udang           10
# 25           yogurt            8
# 26             whey            0
# 27           kasein            0
# 28         meringue            0
# 29      minyak ikan            0
# 30     gelatin ikan            0
# 31            petis            0
# 32           terasi            0
# 33             koya            0
# 34           kerang            0
# 35          mustard            0
# 36  kerupuk kedelai            0
# 37     bumbu kacang            0

# %%
color1= 'steelblue'
color2= 'red'
color3= 'yellow'
line_size = 4
df_v['circum'] = df_v['total_resep'].cumsum()/df_v['total_resep'].sum()*100
df_v_sorted = df_v.sort_values(by='total_resep', ascending=False)
labels = df_v_sorted['bahan_alergen']
data = df_v_sorted['total_resep']

fig, ax = plt.subplots()
ax.bar(labels, data, color=color1)
ax.set_xticklabels(labels, rotation=45, ha='right')
ax2 = ax.twinx()
ax2.plot(labels, df_v['circum'], color=color2, marker="D", ms=7)

plt.axhline(y=80, color=color2, linestyle='--') #threshold line 80%
plt.show()
# Out:
# C:\Users\Faraz\AppData\Local\Temp\ipykernel_12604\3557407810.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=45, ha='right')
