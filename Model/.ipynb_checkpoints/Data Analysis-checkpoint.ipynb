# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as PercentFormatter
import numpy as np

# %%
df = pd.read_excel("Concept_Data Resep_Updated.xlsx")
df
# Out:
#       id                  nama_resep  \
# 0      1             Bubur Hati Ayam
# 1      2      Bubur Hati Ayam Santan
# 2      3       Bubur Pepes Hati Ayam
# 3      4            Bubur Udang Tahu
# 4      5          Bubur Udang Buncis
# ..   ...                         ...
# 222  223               Puree Alpukat
# 223  224                  Granadilla
# 224  225  Vietnamese Lemongrass Beef
# 225  226                    Sup Tofu
# 226  227             Telur Kwek Kwek
#
#                                            bahan_resep     bahan_alergen  \
# 0    nasi, hati ayam, bayam, minyak jagung, garam, ...               NaN
# 1    nasi, hati ayam, wortel, santan, minyak kelapa...               NaN
# 2    nasi, hati ayam, wortel, minyak kelapa, tomat,...               NaN
# 3    nasi, udang giling, santan, tahu, tomat, keman...       udang, tahu
# 4    nasi, udang giling, buncis, minyak jagung, jer...             udang
# ..                                                 ...               ...
# 222                                       alpukat, asi               NaN
# 223                                            markisa               NaN
# 224  daging sapi giling, buncis, paprika, bawang pu...             kecap
# 225  bihun jagung, tauge, sawi hijau, daun bawang, ...  kecap, tofu, mie
# 226  telur puyuh, tepung maizena, tepung terigu, ga...     telur, tepung
#
#     nationality_resep    daerah_resep        umur_resep
# 0          Indonesian      Jawa Timur             6,7,8
# 1          Indonesian      Jawa Timur             6,7,8
# 2          Indonesian             NaN             6,7,8
# 3          Indonesian  Sumatera Barat             6,7,8
# 4          Indonesian      Jawa Timur             6,7,8
# ..                ...             ...               ...
# 222     Amerika Latin         Meksiko  6,7,8,9,10,11,12
# 223     Amerika Latin            Peru  6,7,8,9,10,11,12
# 224     Asia Tenggara         Vietnam                12
# 225     Asia Tenggara         Vietnam                12
# 226     Asia Tenggara        Filipina                12
#
# [227 rows x 7 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['bahan_alergen'] = df['bahan_alergen'].str.split(',') #split alergi yg lebih dari satu
df = df.explode('bahan_alergen') #new row untuk yg dipisah
df
# Out:
#       id              nama_resep  \
# 0      1         Bubur Hati Ayam
# 1      2  Bubur Hati Ayam Santan
# 2      3   Bubur Pepes Hati Ayam
# 3      4        Bubur Udang Tahu
# 3      4        Bubur Udang Tahu
# ..   ...                     ...
# 225  226                Sup Tofu
# 225  226                Sup Tofu
# 225  226                Sup Tofu
# 226  227         Telur Kwek Kwek
# 226  227         Telur Kwek Kwek
#
#                                            bahan_resep bahan_alergen  \
# 0    nasi, hati ayam, bayam, minyak jagung, garam, ...           NaN
# 1    nasi, hati ayam, wortel, santan, minyak kelapa...           NaN
# 2    nasi, hati ayam, wortel, minyak kelapa, tomat,...           NaN
# 3    nasi, udang giling, santan, tahu, tomat, keman...         udang
# 3    nasi, udang giling, santan, tahu, tomat, keman...          tahu
# ..                                                 ...           ...
# 225  bihun jagung, tauge, sawi hijau, daun bawang, ...         kecap
# 225  bihun jagung, tauge, sawi hijau, daun bawang, ...          tofu
# 225  bihun jagung, tauge, sawi hijau, daun bawang, ...           mie
# 226  telur puyuh, tepung maizena, tepung terigu, ga...         telur
# 226  telur puyuh, tepung maizena, tepung terigu, ga...        tepung
#
#     nationality_resep    daerah_resep umur_resep
# 0          Indonesian      Jawa Timur      6,7,8
# 1          Indonesian      Jawa Timur      6,7,8
# 2          Indonesian             NaN      6,7,8
# 3          Indonesian  Sumatera Barat      6,7,8
# 3          Indonesian  Sumatera Barat      6,7,8
# ..                ...             ...        ...
# 225     Asia Tenggara         Vietnam         12
# 225     Asia Tenggara         Vietnam         12
# 225     Asia Tenggara         Vietnam         12
# 226     Asia Tenggara        Filipina         12
# 226     Asia Tenggara        Filipina         12
#
# [440 rows x 7 columns]

# %%
df['bahan_alergen'] = df['bahan_alergen'].str.lstrip()
df
# Out:
#       id              nama_resep  \
# 0      1         Bubur Hati Ayam
# 1      2  Bubur Hati Ayam Santan
# 2      3   Bubur Pepes Hati Ayam
# 3      4        Bubur Udang Tahu
# 3      4        Bubur Udang Tahu
# ..   ...                     ...
# 225  226                Sup Tofu
# 225  226                Sup Tofu
# 225  226                Sup Tofu
# 226  227         Telur Kwek Kwek
# 226  227         Telur Kwek Kwek
#
#                                            bahan_resep bahan_alergen  \
# 0    nasi, hati ayam, bayam, minyak jagung, garam, ...           NaN
# 1    nasi, hati ayam, wortel, santan, minyak kelapa...           NaN
# 2    nasi, hati ayam, wortel, minyak kelapa, tomat,...           NaN
# 3    nasi, udang giling, santan, tahu, tomat, keman...         udang
# 3    nasi, udang giling, santan, tahu, tomat, keman...          tahu
# ..                                                 ...           ...
# 225  bihun jagung, tauge, sawi hijau, daun bawang, ...         kecap
# 225  bihun jagung, tauge, sawi hijau, daun bawang, ...          tofu
# 225  bihun jagung, tauge, sawi hijau, daun bawang, ...           mie
# 226  telur puyuh, tepung maizena, tepung terigu, ga...         telur
# 226  telur puyuh, tepung maizena, tepung terigu, ga...        tepung
#
#     nationality_resep    daerah_resep umur_resep
# 0          Indonesian      Jawa Timur      6,7,8
# 1          Indonesian      Jawa Timur      6,7,8
# 2          Indonesian             NaN      6,7,8
# 3          Indonesian  Sumatera Barat      6,7,8
# 3          Indonesian  Sumatera Barat      6,7,8
# ..                ...             ...        ...
# 225     Asia Tenggara         Vietnam         12
# 225     Asia Tenggara         Vietnam         12
# 225     Asia Tenggara         Vietnam         12
# 226     Asia Tenggara        Filipina         12
# 226     Asia Tenggara        Filipina         12
#
# [440 rows x 7 columns]

# %%
#export data
df.to_csv('cleaned_data.csv', index=False)

# %%
count = df.groupby('bahan_alergen').size()
count
# Out:
# bahan_alergen
# Mie                1
# gelatin            1
# ikan              47
# kacang            28
# kecap             15
# keju              44
# kerupuk udang      1
# krim               1
# mayonnaise         9
# mentega           23
# mie                3
# minyak ikan        2
# minyak kedelai     3
# minyak wijen       9
# pasta             10
# roti              14
# saus tiram         2
# susu              34
# susu sapi          2
# tahu              32
# telur             49
# tempe             14
# tepung            39
# tofu               4
# udang             11
# yogurt             8
# dtype: int64

# %%
#karena beberapa resep tidak ada mengandung beberapa kategori alergen
#krim, whey, kasein, mayonnaise, meringue, minyak ikan, gelatin ikan, ebi, petis, terasi, kerupuk udang, koya, kerang, mustard, kerupuk kedelai, bumbu kacang

new_rows = [#{'bahan_alergen': 'krim', 'total_resep': 0},
            {'bahan_alergen': 'whey', 'total_resep': 0},
            {'bahan_alergen': 'kasein', 'total_resep': 0},
            #{'bahan_alergen': 'mayonnaise', 'total_resep': 0},
            {'bahan_alergen': 'meringue', 'total_resep': 0},
            {'bahan_alergen': 'minyak ikan', 'total_resep': 0},
            {'bahan_alergen': 'gelatin ikan', 'total_resep': 0},
            #{'bahan_alergen': 'ebi', 'total_resep': 0},
            {'bahan_alergen': 'petis', 'total_resep': 0},
            {'bahan_alergen': 'terasi', 'total_resep': 0},
            #{'bahan_alergen': 'kerupuk udang', 'total_resep': 0},
            {'bahan_alergen': 'koya', 'total_resep': 0},
            {'bahan_alergen': 'kerang', 'total_resep': 0},
            {'bahan_alergen': 'mustard', 'total_resep': 0},
            {'bahan_alergen': 'kerupuk kedelai', 'total_resep': 0},
            {'bahan_alergen': 'bumbu kacang', 'total_resep': 0}]

df_y = pd.DataFrame(new_rows)

# %%
df_v = df.groupby('bahan_alergen')['nama_resep'].count().reset_index()
df_v.columns = ['bahan_alergen', 'total_resep']
df_v
# Out:
#      bahan_alergen  total_resep
# 0              Mie            1
# 1          gelatin            1
# 2             ikan           47
# 3           kacang           28
# 4            kecap           15
# 5             keju           44
# 6    kerupuk udang            1
# 7             krim            1
# 8       mayonnaise            9
# 9          mentega           23
# 10             mie            3
# 11     minyak ikan            2
# 12  minyak kedelai            3
# 13    minyak wijen            9
# 14           pasta           10
# 15            roti           14
# 16      saus tiram            2
# 17            susu           34
# 18       susu sapi            2
# 19            tahu           32
# 20           telur           49
# 21           tempe           14
# 22          tepung           39
# 23            tofu            4
# 24           udang           11
# 25          yogurt            8

# %%
df_v = pd.concat([df_v, df_y], ignore_index=True)

# %%
df_v_sorted = df_v.sort_values(by='total_resep',ascending=False)
print(df_v_sorted)
# Out:
#       bahan_alergen  total_resep
# 20            telur           49
# 2              ikan           47
# 5              keju           44
# 22           tepung           39
# 17             susu           34
# 19             tahu           32
# 3            kacang           28
# 9           mentega           23
# 4             kecap           15
# 15             roti           14
# 21            tempe           14
# 24            udang           11
# 14            pasta           10
# 13     minyak wijen            9
# 8        mayonnaise            9
# 25           yogurt            8
# 23             tofu            4
# 10              mie            3
# 12   minyak kedelai            3
# 16       saus tiram            2
# 18        susu sapi            2
# 11      minyak ikan            2
# 0               Mie            1
# 1           gelatin            1
# 7              krim            1
# 6     kerupuk udang            1
# 26             whey            0
# 27           kasein            0
# 28         meringue            0
# 29      minyak ikan            0
# 30     gelatin ikan            0
# 31            petis            0
# 32           terasi            0
# 33             koya            0
# 34           kerang            0
# 35          mustard            0
# 36  kerupuk kedelai            0
# 37     bumbu kacang            0

# %%
color1= 'steelblue'
color2= 'red'
color3= 'yellow'
line_size = 4
df_v['circum'] = df_v['total_resep'].cumsum()/df_v['total_resep'].sum()*100
df_v_sorted = df_v.sort_values(by='total_resep', ascending=False)
labels = df_v_sorted['bahan_alergen']
data = df_v_sorted['total_resep']

fig, ax = plt.subplots()
ax.bar(labels, data, color=color1)
ax.set_xticklabels(labels, rotation=45, ha='right')
ax2 = ax.twinx()
ax2.plot(labels, df_v['circum'], color=color2, marker="D", ms=7)

plt.axhline(y=80, color=color2, linestyle='--') #threshold line 80%
plt.show()
# Out:
# C:\Users\Faraz\AppData\Local\Temp\ipykernel_7492\3557407810.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=45, ha='right')
