# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import jaccard_score
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_excel("Concept_Data Resep_Updated.xlsx")
df = df.fillna('')
# df['umur_resep'] = df['umur_resep'].astype(str)
# df['umur_resep'] = df['umur_resep'].apply(lambda x: list(map(int, x.split(','))))

# %%
df_clean = df.copy()
df_clean
# Out:
#       id                  nama_resep  \
# 0      1             Bubur Hati Ayam
# 1      2      Bubur Hati Ayam Santan
# 2      3       Bubur Pepes Hati Ayam
# 3      4            Bubur Udang Tahu
# 4      5          Bubur Udang Buncis
# ..   ...                         ...
# 222  223               Puree Alpukat
# 223  224                  Granadilla
# 224  225  Vietnamese Lemongrass Beef
# 225  226                    Sup Tofu
# 226  227             Telur Kwek Kwek
#
#                                            bahan_resep     bahan_alergen  \
# 0    nasi, hati ayam, bayam, minyak jagung, garam, ...
# 1    nasi, hati ayam, wortel, santan, minyak kelapa...
# 2    nasi, hati ayam, wortel, minyak kelapa, tomat,...
# 3    nasi, udang giling, santan, tahu, tomat, keman...       udang, tahu
# 4    nasi, udang giling, buncis, minyak jagung, jer...             udang
# ..                                                 ...               ...
# 222                                       alpukat, asi
# 223                                            markisa
# 224  daging sapi giling, buncis, paprika, bawang pu...             kecap
# 225  bihun jagung, tauge, sawi hijau, daun bawang, ...  kecap, tofu, mie
# 226  telur puyuh, tepung maizena, tepung terigu, ga...     telur, tepung
#
#     nationality_resep    daerah_resep        umur_resep
# 0          Indonesian      Jawa Timur             6,7,8
# 1          Indonesian      Jawa Timur             6,7,8
# 2          Indonesian                             6,7,8
# 3          Indonesian  Sumatera Barat             6,7,8
# 4          Indonesian      Jawa Timur             6,7,8
# ..                ...             ...               ...
# 222     Amerika Latin         Meksiko  6,7,8,9,10,11,12
# 223     Amerika Latin            Peru  6,7,8,9,10,11,12
# 224     Asia Tenggara         Vietnam                12
# 225     Asia Tenggara         Vietnam                12
# 226     Asia Tenggara        Filipina                12
#
# [227 rows x 7 columns]

# %%
df_clean[['bahan_resep','bahan_alergen']] = df_clean[['bahan_resep','bahan_alergen']].replace(to_replace=r'[^\w\s]', value=' ', regex=True)
df_clean
# Out:
#       id                  nama_resep  \
# 0      1             Bubur Hati Ayam
# 1      2      Bubur Hati Ayam Santan
# 2      3       Bubur Pepes Hati Ayam
# 3      4            Bubur Udang Tahu
# 4      5          Bubur Udang Buncis
# ..   ...                         ...
# 222  223               Puree Alpukat
# 223  224                  Granadilla
# 224  225  Vietnamese Lemongrass Beef
# 225  226                    Sup Tofu
# 226  227             Telur Kwek Kwek
#
#                                            bahan_resep     bahan_alergen  \
# 0    nasi  hati ayam  bayam  minyak jagung  garam  ...
# 1    nasi  hati ayam  wortel  santan  minyak kelapa...
# 2    nasi  hati ayam  wortel  minyak kelapa  tomat ...
# 3    nasi  udang giling  santan  tahu  tomat  keman...       udang  tahu
# 4    nasi  udang giling  buncis  minyak jagung  jer...             udang
# ..                                                 ...               ...
# 222                                       alpukat  asi
# 223                                            markisa
# 224  daging sapi giling  buncis  paprika  bawang pu...             kecap
# 225  bihun jagung  tauge  sawi hijau  daun bawang  ...  kecap  tofu  mie
# 226  telur puyuh  tepung maizena  tepung terigu  ga...     telur  tepung
#
#     nationality_resep    daerah_resep        umur_resep
# 0          Indonesian      Jawa Timur             6,7,8
# 1          Indonesian      Jawa Timur             6,7,8
# 2          Indonesian                             6,7,8
# 3          Indonesian  Sumatera Barat             6,7,8
# 4          Indonesian      Jawa Timur             6,7,8
# ..                ...             ...               ...
# 222     Amerika Latin         Meksiko  6,7,8,9,10,11,12
# 223     Amerika Latin            Peru  6,7,8,9,10,11,12
# 224     Asia Tenggara         Vietnam                12
# 225     Asia Tenggara         Vietnam                12
# 226     Asia Tenggara        Filipina                12
#
# [227 rows x 7 columns]

# %%
data = pd.DataFrame({
    'nama_resep' : df['nama_resep'],
    'bahan_resep_dan_alergen': df_clean['bahan_resep'].astype(str) + ' ' + df_clean['bahan_alergen'].astype(str),
    'umur_resep': df_clean['umur_resep']
})
data
# Out:
#                      nama_resep  \
# 0               Bubur Hati Ayam
# 1        Bubur Hati Ayam Santan
# 2         Bubur Pepes Hati Ayam
# 3              Bubur Udang Tahu
# 4            Bubur Udang Buncis
# ..                          ...
# 222               Puree Alpukat
# 223                  Granadilla
# 224  Vietnamese Lemongrass Beef
# 225                    Sup Tofu
# 226             Telur Kwek Kwek
#
#                                bahan_resep_dan_alergen        umur_resep
# 0    nasi  hati ayam  bayam  minyak jagung  garam  ...             6,7,8
# 1    nasi  hati ayam  wortel  santan  minyak kelapa...             6,7,8
# 2    nasi  hati ayam  wortel  minyak kelapa  tomat ...             6,7,8
# 3    nasi  udang giling  santan  tahu  tomat  keman...             6,7,8
# 4    nasi  udang giling  buncis  minyak jagung  jer...             6,7,8
# ..                                                 ...               ...
# 222                                      alpukat  asi   6,7,8,9,10,11,12
# 223                                           markisa   6,7,8,9,10,11,12
# 224  daging sapi giling  buncis  paprika  bawang pu...                12
# 225  bihun jagung  tauge  sawi hijau  daun bawang  ...                12
# 226  telur puyuh  tepung maizena  tepung terigu  ga...                12
#
# [227 rows x 3 columns]

# %%
# user_age = 9
# #filtered_data = data.loc[(data['umur_resep'] == user_age)]
# #filtered_data= [umur for umur in data if data['umur_resep'] == user_age() ]
# filtered_data = data[data['umur_resep'].apply(lambda x: user_age in x )]
# filtered_pd = pd.DataFrame(filtered_data)
# filtered_pd
#print(filtered_data)

# %%
#cosine similarity (ini g valid)
# user_input = 'susu, kacang'
# def find_recipes_cosine(data_matrix, user_input, min_similarity=1) :
#     vectorizer = CountVectorizer()
#     data_matrix = vectorizer.fit_transform(data['bahan_resep_dan_alergen'])
#     user_matrix = vectorizer.transform([user_input])
#     similarities = cosine_similarity(user_matrix, data_matrix)
#     #cari top 3 recipe
    
#     top_n = 10
#     top_indices = np.argsort(similarities[0])
#     top_recipes = [(df[['nama_resep','bahan_resep','bahan_alergen']].iloc[i], similarities[0,i]) for i in top_indices if similarities [0,i] <= min_similarity]

#     return top_recipes

# user_input = "susu"
# recommended_recipe = find_recipes_cosine(df, user_input)
# for recipe in recommended_recipe:
#     print("Recipe:", recipe[0])
#     print("Similarity Score:", recipe[1])
#     print()

# %%
user_input = "susu telur kacang tempe tahu tofu"
def find_recipes_sim(data_matrix, user_input, min_similarity = 0):
    vectorizer = CountVectorizer()
    data_matrix = vectorizer.fit_transform(data['bahan_resep_dan_alergen'])
    user_matrix = vectorizer.transform([user_input])
    data_matrix_sets = [row.indices for row in data_matrix]
    user_matrix_sets = [row.indices for row in user_matrix][0]

    similarities = []
    for row in data_matrix_sets:
        intersection = len(list(set(user_matrix_sets).intersection(row)))
        similarity = 2*float(intersection)/(len(set(user_matrix_sets)) + len(set(row)))
        similarities.append(similarity)

    top_recipes = [(df.loc[i, ['nama_resep', 'bahan_resep', 'bahan_alergen', 'umur_resep']], similarities[i]) 
                   for i in np.argsort(similarities) if similarities[i] == min_similarity]

    return top_recipes

recommended_recipe = find_recipes_sim(df, user_input)

# for recipe in recommended_recipe:
#      print(recipe[0])
#      print("Similarity Score:", recipe[1])
#      print()

recipe_result = pd.DataFrame(
    [
        {**recipe[0].to_dict(), "similarity_score": recipe[1]}
        for recipe in recommended_recipe
    ]
)

recipe_result
# Out:
#                           nama_resep  \
# 0                    Bubur Hati Ayam
# 1            Bubur Susu Oatmeal Keju
# 2                        Pure Wortel
# 3                  Smoothie Stroberi
# 4                    Smoothie Pepaya
# ..                               ...
# 90                Bubur Udang Buncis
# 91                 Siomay Ayam Udang
# 92                  Pure Pisang Apel
# 93  Bubur Kanju Rumbi Ayam dan Udang
# 94                    Bubur Tenggiri
#
#                                           bahan_resep  \
# 0   nasi, hati ayam, bayam, minyak jagung, garam, ...
# 1                             air, oatmeal, ASI, keju
# 2                                         wortel, ASI
# 3                                       stroberi, ASI
# 4                                         pepaya, air
# ..                                                ...
# 90  nasi, udang giling, buncis, minyak jagung, jer...
# 91  daging ayam, udang, tepung tapioka, minyak wij...
# 92                               apel, pisang, yogurt
# 93  nasi, ayam, udang, wortel, jagung pipil, santa...
# 94  beras, ikan tenggiri, buncis, kaldu ayam, miny...
#
#                                  bahan_alergen umur_resep  similarity_score
# 0                                                   6,7,8               0.0
# 1                                         keju      6,7,8               0.0
# 2                                                   6,7,8               0.0
# 3                                                   6,7,8               0.0
# 4                                                   6,7,8               0.0
# ..                                         ...        ...               ...
# 90                                       udang      6,7,8               0.0
# 91  udang,tepung,minyak wijen,kecap,saus tiram      6,7,8               0.0
# 92                                      yogurt      6,7,8               0.0
# 93                                       udang      6,7,8               0.0
# 94                                        ikan      6,7,8               0.0
#
# [95 rows x 5 columns]

# %%
recipe_result['umur_resep'] = recipe_result['umur_resep'].astype(str)
recipe_result['umur_resep'] = recipe_result['umur_resep'].apply(lambda x: list(map(int, x.split(','))))

# %%
user_age = 12
filtered_data = recipe_result[recipe_result['umur_resep'].apply(lambda x: user_age in x )]
filtered_pd = pd.DataFrame(filtered_data)
filtered_pd
# Out:
#                     nama_resep  \
# 32  Vietnamese Lemongrass Beef
# 33                  Granadilla
# 34               Puree Alpukat
# 35                       Lugaw
# 36                  Puree Labu
# 37                       Okayu
# 38           Bubur Ayam Hainan
# 39   Bubur Nasi Hainan Seafood
# 40               Beef Teriyaki
#
#                                           bahan_resep  \
# 32  daging sapi giling, buncis, paprika, bawang pu...
# 33                                            markisa
# 34                                       alpukat, asi
# 35        beras putih, kaldu ayam, bawang putih, jahe
# 36                                   labu kuning, asi
# 37              rumput laut, beras jepang, air, garam
# 38  nasi putih, air, serai, daun salam, kaldu ayam...
# 39  udang, teri, beras, ayam, air, chicken fat oil...
# 40  daging, bawang bombay, bawang putih, mentega, ...
#
#                                    bahan_alergen                umur_resep  \
# 32                                         kecap                      [12]
# 33                                                [6, 7, 8, 9, 10, 11, 12]
# 34                                                [6, 7, 8, 9, 10, 11, 12]
# 35                                                [6, 7, 8, 9, 10, 11, 12]
# 36                                                [6, 7, 8, 9, 10, 11, 12]
# 37                                                [6, 7, 8, 9, 10, 11, 12]
# 38                                                [6, 7, 8, 9, 10, 11, 12]
# 39  udang, ikan, keju, minyak wijen, minyak ikan  [6, 7, 8, 9, 10, 11, 12]
# 40                          mentega, keju, kecap  [6, 7, 8, 9, 10, 11, 12]
#
#     similarity_score
# 32               0.0
# 33               0.0
# 34               0.0
# 35               0.0
# 36               0.0
# 37               0.0
# 38               0.0
# 39               0.0
# 40               0.0

# %%
user_input = "susu, kacang, tempe, tahu, tofu"
def find_recipes_jaccard(data_matrix, user_input, min_similarity = 0):
    vectorizer = CountVectorizer()
    data_matrix = vectorizer.fit_transform(data['bahan_resep_dan_alergen'])
    user_matrix = vectorizer.transform([user_input])

    data_matrix_sets = [row.indices for row in data_matrix]
    user_matrix_sets = [row.indices for row in user_matrix][0]

    similarities = []
    for row in data_matrix_sets:
        intersection = len(list(set(user_matrix_sets).intersection(row)))
        union = (len(set(user_matrix_sets)) + len(row)) - intersection
        jaccard_sim = float(intersection) / union
        similarities.append(jaccard_sim)

    top_recipes = [(df.loc[i, ['nama_resep', 'bahan_resep', 'bahan_alergen', 'umur_resep']], similarities[i]) 
                   for i in np.argsort(similarities) if similarities[i] == min_similarity]

    return top_recipes

recommended_recipe = find_recipes_jaccard(df, user_input)
# for recipe in recommended_recipe:
#     print("Recipe:", recipe[0])
#     print("Similarity Score:", recipe[1])
#     print()

recipe_result = pd.DataFrame(
    [
        {**recipe[0].to_dict(), "similarity_score": recipe[1]}
        for recipe in recommended_recipe
    ]
)

recipe_result
# Out:
#                            nama_resep  \
# 0                     Bubur Hati Ayam
# 1                      Bubur Havermut
# 2              Bubur Oat Rasa Cokelat
# 3               Bubur Saring Makaroni
# 4              Bubur Tenggiri Brokoli
# ..                                ...
# 115      Finger Food Kentang Panggang
# 116  Bubur Kanju Rumbi Ayam dan Udang
# 117                Bubur Telur Daging
# 118                    Bubur Tenggiri
# 119                Bubur Ayam Mentega
#
#                                            bahan_resep  \
# 0    nasi, hati ayam, bayam, minyak jagung, garam, ...
# 1            havermut, air, avokad, kuning telur rebus
# 2                         oat, bubuk cokelat, air, ASI
# 3    bawang bombay, ayam cincang, makaroni, wortel,...
# 4    ikan tenggiri, kentang, wortel, air, brokoli, ...
# ..                                                 ...
# 115                                            kentang
# 116  nasi, ayam, udang, wortel, jagung pipil, santa...
# 117  nasi, daging sapi, telur, brokoli, air, bawag ...
# 118  beras, ikan tenggiri, buncis, kaldu ayam, miny...
# 119  beras, daging ayam giling, telur, wortel, air ...
#
#                    bahan_alergen umur_resep  similarity_score
# 0                                     6,7,8               0.0
# 1                          telur      6,7,8               0.0
# 2                                     6,7,8               0.0
# 3                   pasta,tepung      6,7,8               0.0
# 4                           ikan      6,7,8               0.0
# ..                           ...        ...               ...
# 115                                   6,7,8               0.0
# 116                        udang      6,7,8               0.0
# 117  minyak wijen,kecap, mentega      6,7,8               0.0
# 118                         ikan      6,7,8               0.0
# 119               mentega, telur      6,7,8               0.0
#
# [120 rows x 5 columns]

# %%
# user_input = "susu  udang kacang ikan gluten "
# vectorizer = CountVectorizer()
# data_matrix = vectorizer.fit_transform(data['bahan_resep_dan_alergen'])
# user_matrix = vectorizer.transform([user_input])
# data_matrix_sets = [row.indices for row in data_matrix]
# user_matrix_sets = [row.indices for row in user_matrix][0]

# print(data_matrix.shape)
# print(data_matrix.toarray()[200])
# print(data_matrix_sets[1])
# data_words = vectorizer.get_feature_names_out()
# print(data_words)

# %%
recipe_result['umur_resep'] = recipe_result['umur_resep'].astype(str)
recipe_result['umur_resep'] = recipe_result['umur_resep'].apply(lambda x: list(map(int, x.split(','))))

# %%
user_age = 12
filtered_data = recipe_result[recipe_result['umur_resep'].apply(lambda x: user_age in x )]
filtered_pd = pd.DataFrame(filtered_data)
filtered_pd
# Out:
#                     nama_resep  \
# 37               Salmon Mentai
# 38                Chawan Mushi
# 39               Beef Teriyaki
# 40   Bubur Nasi Hainan Seafood
# 41           Bubur Ayam Hainan
# 43      Bubur Fu Yung Hai Ayam
# 44                  Puree Labu
# 45                       Lugaw
# 46       Tortilla telur gulung
# 47               Puree Alpukat
# 48                  Granadilla
# 49  Vietnamese Lemongrass Beef
# 50                       Okayu
# 71             Telur Kwek Kwek
#
#                                           bahan_resep  \
# 37  salmon, kuning telur ayam, keju belcube, air, ...
# 38  telur ayam, santan, air, bawang goreng, daun b...
# 39  daging, bawang bombay, bawang putih, mentega, ...
# 40  udang, teri, beras, ayam, air, chicken fat oil...
# 41  nasi putih, air, serai, daun salam, kaldu ayam...
# 43  beras organik, telur ayam, daging ayam, wortel...
# 44                                   labu kuning, asi
# 45        beras putih, kaldu ayam, bawang putih, jahe
# 46  tortilla, telur, daun selada, bawang bombay, g...
# 47                                       alpukat, asi
# 48                                            markisa
# 49  daging sapi giling, buncis, paprika, bawang pu...
# 50              rumput laut, beras jepang, air, garam
# 71  telur puyuh, tepung maizena, tepung terigu, ga...
#
#                                    bahan_alergen                umur_resep  \
# 37                          telur, mentega, ikan  [6, 7, 8, 9, 10, 11, 12]
# 38                                         telur  [6, 7, 8, 9, 10, 11, 12]
# 39                          mentega, keju, kecap  [6, 7, 8, 9, 10, 11, 12]
# 40  udang, ikan, keju, minyak wijen, minyak ikan  [6, 7, 8, 9, 10, 11, 12]
# 41                                                [6, 7, 8, 9, 10, 11, 12]
# 43                                         telur  [6, 7, 8, 9, 10, 11, 12]
# 44                                                [6, 7, 8, 9, 10, 11, 12]
# 45                                                [6, 7, 8, 9, 10, 11, 12]
# 46                          telur, keju, mentega                      [12]
# 47                                                [6, 7, 8, 9, 10, 11, 12]
# 48                                                [6, 7, 8, 9, 10, 11, 12]
# 49                                         kecap                      [12]
# 50                                                [6, 7, 8, 9, 10, 11, 12]
# 71                                 telur, tepung                      [12]
#
#     similarity_score
# 37               0.0
# 38               0.0
# 39               0.0
# 40               0.0
# 41               0.0
# 43               0.0
# 44               0.0
# 45               0.0
# 46               0.0
# 47               0.0
# 48               0.0
# 49               0.0
# 50               0.0
# 71               0.0
